# %% [markdown]
# # "Fuska" på nationella prov

# %%
import matplotlib.pyplot as plt

a_vals = [] #skapar en tom lista

for x in range(1,10):
    a = round(5*(2+4/x),2)
    a_vals.append(a) #vi spara värden på a i listan

plt.plot(a_vals)
